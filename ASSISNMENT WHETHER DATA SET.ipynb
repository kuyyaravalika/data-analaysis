# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv(r"C:\Users\K Ravalika\Downloads\Weather_Data.csv")

# %%
data1
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0      1/1/2012 0:00    -1.3              -3.5         18                9
# 1      1/1/2012 1:00     7.4               2.8         20               24
# 2      1/1/2012 2:00    15.7              13.4         21               26
# 3      1/1/2012 3:00     4.9              -2.6         27               15
# 4      1/1/2012 4:00   -13.4             -19.7         30                4
# ...              ...     ...               ...        ...              ...
# 8779  9/30/2012 5:00     1.4              -3.7         97               22
# 8780  9/30/2012 6:00    -4.6              -9.5         98               11
# 8781  9/30/2012 7:00     1.5              -6.3         99               30
# 8782  9/30/2012 8:00    -6.3             -13.5         99               15
# 8783  9/30/2012 9:00    24.5              14.7        100               11
#
#       Visibility_km  Press_kPa        Weather
# ...

# %%
data1.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.3              -3.5         18                9
# 1  1/1/2012 1:00     7.4               2.8         20               24
# 2  1/1/2012 2:00    15.7              13.4         21               26
# 3  1/1/2012 3:00     4.9              -2.6         27               15
# 4  1/1/2012 4:00   -13.4             -19.7         30                4
#
#    Visibility_km  Press_kPa        Weather
# 0           25.0      98.67          Clear
# 1           24.1      99.37           Rain
# 2           25.0      99.84         Cloudy
# 3           24.1     100.94   Mainly Clear
# 4           25.0     102.32  Mostly Cloudy

# %%
#1) Find all the unique 'Wind Speed' values in the data. 
data1["Wind Speed_km/h"].unique()
# Out:
# array([ 9, 24, 26, 15,  4,  0, 19, 17, 11, 22, 35, 13, 20,  6,  7, 30, 32,
#        41, 39, 28, 44, 33, 37, 52, 46,  2, 50, 48, 57, 63, 43, 83, 70, 54],
#       dtype=int64)

# %%
# 2) Find the number of times when the 'Weather is exactly Clear'. 
data1.loc[data1["Weather"]==(data1["Weather"]=="clear"),"Weather"].value_counts()
# Out:
# Series([], Name: Weather, dtype: int64)

# %%
# 3) Find the number of times when the 'Wind Speed was exactly 4 km/h'. 
data1.loc[data1["Wind Speed_km/h"]==(data1["Wind Speed_km/h"]=="clear"),"Wind Speed_km/h"].value_counts()
# Out:
# 0    309
# Name: Wind Speed_km/h, dtype: int64

# %%
# 4) Find out all the Null Values in the data. 
data1.isnull().value_counts()
# Out:
# Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather
# False      False   False             False      False            False          False      False      8784
# dtype: int64

# %%
# 5) Rename the column name 'Weather' of the dataframe to 'Weather Condition'.
data1.rename(columns={"Weather":"Weather condition"},inplace=True)

# %%
data1
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0      1/1/2012 0:00    -1.3              -3.5         18                9
# 1      1/1/2012 1:00     7.4               2.8         20               24
# 2      1/1/2012 2:00    15.7              13.4         21               26
# 3      1/1/2012 3:00     4.9              -2.6         27               15
# 4      1/1/2012 4:00   -13.4             -19.7         30                4
# ...              ...     ...               ...        ...              ...
# 8779  9/30/2012 5:00     1.4              -3.7         97               22
# 8780  9/30/2012 6:00    -4.6              -9.5         98               11
# 8781  9/30/2012 7:00     1.5              -6.3         99               30
# 8782  9/30/2012 8:00    -6.3             -13.5         99               15
# 8783  9/30/2012 9:00    24.5              14.7        100               11
#
#       Visibility_km  Press_kPa Weather condition
# ...

# %%
# 6) What is the mean 'Visibility' ? 
data1["Visibility_km"].mean()
# Out:
# 27.664446721311478

# %%
# 7) What is the Standard Deviation of 'Pressure' in this data? 
data1["Press_kPa"].std()
# Out:
# 0.8440047459486459

# %%
# 8) What is the Variance of 'Relative Humidity' in this data ? 
data1["Rel Hum_%"].var()
# Out:
# 286.2485501985015

# %%
#9) Find all instances when 'Snow' was recorded. 
data1.loc[data1["Weather condition"]=="Snow"]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 11     1/1/2012 11:00    -6.2              -9.6         37               35
# 70     3/1/2012 22:00    -4.0              -6.6         62               22
# 73      4/1/2012 1:00     2.3              -3.4         64               35
# 105     5/1/2012 9:00    -1.8              -4.2         73               15
# 112    5/1/2012 16:00     1.7              -0.3         75                6
# ...               ...     ...               ...        ...              ...
# 8573  9/22/2012 13:00    -6.0             -10.2         82               19
# 8650  9/25/2012 18:00    -4.6              -6.6         52                4
# 8671  9/26/2012 15:00    -5.9             -10.5         60               13
# 8713   9/28/2012 1:00    -5.2              -7.8         72               33
# 8734   9/28/2012 8:00     0.7              -1.2         79               30
#
#       Visibility_km  Press_kPa Weather condition
# ...

# %%
#10) Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'. 
data1.loc[(data1["Wind Speed_km/h"])]
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 9    1/1/2012 9:00    20.0               3.8         35               17
# 24   2/1/2012 0:00    21.0               7.7         46               13
# 26   2/1/2012 2:00    14.3               4.9         50               15
# 15  1/1/2012 15:00    28.3              21.0         41               17
# 4    1/1/2012 4:00   -13.4             -19.7         30                4
# ..             ...     ...               ...        ...              ...
# 22  1/1/2012 22:00    14.1               8.3         45                9
# 11  1/1/2012 11:00    -6.2              -9.6         37               35
# 30   2/1/2012 6:00    18.2              16.1         51               11
# 15  1/1/2012 15:00    28.3              21.0         41               17
# 11  1/1/2012 11:00    -6.2              -9.6         37               35
#
#     Visibility_km  Press_kPa Weather condition
# ...

# %%
# 11) What is the Mean value of each column against each 'Weather Condition ? 
g=data1.groupby("Weather condition")

# %%
g[["Press_kPa","Temp_C","Rel Hum_%","Wind Speed_km/h","Visibility_km","Temp_C"]].mean()
# Out:
#                                           Press_kPa     Temp_C  Rel Hum_%  \
# Weather condition
# Clear                                    101.084495   6.825716  67.127451
# Cloudy                                   101.056852   7.970544  67.349537
# Drizzle                                  101.099268   7.353659  69.048780
# Drizzle,Fog                              100.820750   8.067500  70.062500
# Drizzle,Ice Pellets,Fog                   99.440000   0.400000  52.000000
# Drizzle,Snow                             100.490000   1.050000  44.000000
# Drizzle,Snow,Fog                         100.971333   0.693333  69.800000
# Fog                                      101.149400   4.303333  66.466667
# Freezing Drizzle                         101.070000  -5.657143  68.857143
# Freezing Drizzle,Fog                     100.851667  -2.533333  64.000000
# Freezing Drizzle,Haze                    101.136667  -5.433333  63.333333
# ...

# %%
# 12) What is the Minimum & Maximum value of each column against each 'Weather Condition ? 
g[["Press_kPa","Temp_C","Rel Hum_%","Wind Speed_km/h","Visibility_km","Temp_C"]].min()
# Out:
#                                          Press_kPa  Temp_C  Rel Hum_%  \
# Weather condition
# Clear                                        97.75   -23.3         18
# Cloudy                                       97.52   -21.4         20
# Drizzle                                      98.29     1.1         37
# Drizzle,Fog                                  98.32     0.0         38
# Drizzle,Ice Pellets,Fog                      99.44     0.4         52
# Drizzle,Snow                                100.27     0.9         39
# Drizzle,Snow,Fog                             99.26     0.3         46
# Fog                                          97.97   -16.0         21
# Freezing Drizzle                             99.75    -9.0         43
# Freezing Drizzle,Fog                         98.81    -6.4         31
# Freezing Drizzle,Haze                       100.55    -5.8         32
# Freezing Drizzle,Snow                        99.74    -8.3         37
# ...

# %%
g[["Press_kPa","Temp_C","Rel Hum_%","Wind Speed_km/h","Visibility_km","Temp_C"]].max()
# Out:
#                                          Press_kPa  Temp_C  Rel Hum_%  \
# Weather condition
# Clear                                       103.63    32.8        100
# Cloudy                                      103.52    30.5        100
# Drizzle                                     103.58    18.8         97
# Drizzle,Fog                                 103.56    19.9         98
# Drizzle,Ice Pellets,Fog                      99.44     0.4         52
# Drizzle,Snow                                100.71     1.2         49
# Drizzle,Snow,Fog                            102.47     1.1         94
# Fog                                         103.22    20.8         99
# Freezing Drizzle                            101.78    -2.3         89
# Freezing Drizzle,Fog                        103.01    -0.3         80
# Freezing Drizzle,Haze                       101.83    -5.0         81
# Freezing Drizzle,Snow                       101.15    -3.3         90
# ...

# %%
#13) Show all the Records where Weathfoger Condition is Fog. 
data1.loc[data1["Weather condition"]=="Fog"]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 13     1/1/2012 13:00     9.5               7.8         40               13
# 53      3/1/2012 5:00    -3.6              -4.3         57                7
# 136    6/1/2012 16:00    14.8              13.5         80               19
# 197     9/1/2012 5:00     2.1               0.7         43               11
# 278   12/1/2012 14:00     1.2               0.6         70               13
# ...               ...     ...               ...        ...              ...
# 8475  9/18/2012 11:00     6.2               5.4         56                7
# 8511  9/19/2012 22:00    15.7              15.4         66                7
# 8518   9/19/2012 8:00    -2.9              -4.5         68                6
# 8537   9/20/2012 3:00    -0.5              -2.1         74                7
# 8771  9/30/2012 19:00    12.8              12.2         91               19
#
#       Visibility_km  Press_kPa Weather condition
# ...

# %%
# 14) Find all instances when 'Weather is Clear' or 'Visibility is above 40'.
data1.loc[(data1["Weather condition"]=="Clear")|(data1["Visibility_km"]>40)]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       1/1/2012 0:00    -1.3              -3.5         18                9
# 9       1/1/2012 9:00    20.0               3.8         35               17
# 16     1/1/2012 16:00    23.8              17.6         42                9
# 17     1/1/2012 17:00    -6.8              -9.8         42               20
# 18     1/1/2012 18:00     2.3              -2.4         42                6
# ...               ...     ...               ...        ...              ...
# 8774  9/30/2012 21:00    23.0              14.7         92               13
# 8777   9/30/2012 3:00     9.3               5.8         95                9
# 8779   9/30/2012 5:00     1.4              -3.7         97               22
# 8780   9/30/2012 6:00    -4.6              -9.5         98               11
# 8781   9/30/2012 7:00     1.5              -6.3         99               30
#
#       Visibility_km  Press_kPa Weather condition
# ...

# %%
#15) Find all instances when : 
# 'Weather is Clear' and 'Relative Humidity is greater than 50' 
data1.loc[(data1["Weather condition"]=="Clear")&(data1["Rel Hum_%"]>50)]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 35     2/1/2012 11:00     9.1               6.2         53                6
# 37     2/1/2012 13:00   -12.0             -18.2         54               22
# 40     2/1/2012 16:00    21.5              10.9         54                0
# 50      3/1/2012 2:00    18.9              16.2         56                9
# 51      3/1/2012 3:00    22.2               5.5         57               19
# ...               ...     ...               ...        ...              ...
# 8735   9/28/2012 9:00    14.2              12.9         80                4
# 8743  9/29/2012 15:00    17.7               7.8         81                9
# 8768  9/30/2012 16:00    18.2               8.8         90                4
# 8770  9/30/2012 18:00    24.6              12.6         90               15
# 8781   9/30/2012 7:00     1.5              -6.3         99               30
#
#       Visibility_km  Press_kPa Weather condition
# ...

# %%
#or 
#B. 'Visibility is above 40'
data1.loc[data1["Visibility_km"]>40]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 9       1/1/2012 9:00    20.0               3.8         35               17
# 17     1/1/2012 17:00    -6.8              -9.8         42               20
# 18     1/1/2012 18:00     2.3              -2.4         42                6
# 19     1/1/2012 19:00   -12.7             -17.2         43               17
# 23     1/1/2012 23:00    29.5              16.8         45                4
# ...               ...     ...               ...        ...              ...
# 8759   9/29/2012 9:00    -2.1             -10.9         86               24
# 8774  9/30/2012 21:00    23.0              14.7         92               13
# 8777   9/30/2012 3:00     9.3               5.8         95                9
# 8779   9/30/2012 5:00     1.4              -3.7         97               22
# 8780   9/30/2012 6:00    -4.6              -9.5         98               11
#
#       Visibility_km  Press_kPa Weather condition
# ...
